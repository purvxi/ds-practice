# %% [markdown]
# <a href="https://colab.research.google.com/github/purvxi/ds-practice/blob/main/numpy/01_numpy_basics_marks.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
marks=np.array([78, 85, 62, 90, 45, 88, 76, 55, 95, 70])
marks.shape
marks.size
# Out:
# 10

# %%
marks.mean()
# Out:
# np.float64(74.4)

# %%
marks.max()
# Out:
# np.int64(95)

# %%
marks.min()
# Out:
# np.int64(45)

# %%
np.sort(marks)
# Out:
# array([45, 55, 62, 70, 76, 78, 85, 88, 90, 95])

# %%
marks[marks>85]
# Out:
# array([90, 88, 95])
